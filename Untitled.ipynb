# %%
import cv2
import numpy as np
import pandas as pd
import json

# %%
# splitting video into frames

vidcap = cv2.VideoCapture('data/example/example.mp4')
# take the first frame of the video
success, image = vidcap.read()
count = 0

# while success:
#     # save frame as JPEG file
#     cv2.imwrite(f"data/example/frames/frame{count}.jpg", image)
#     # take the next frame of the video
#     success, image = vidcap.read()
#     count += 1

# %%
image.shape
# Out:
# (1080, 1920, 3)

# %%
image_fragment = image[ : 100][ : 100]
image_fragment.shape
# Out:
# (100, 1920, 3)

# %%
cv2.imwrite(f"data/example/image_fragment.jpg", image_fragment)
# Out:
# True

# %%
cv2.imwrite(f"data/example/image.jpg", image)
# Out:
# True

# %%
with open('data/cars.json') as json_file:
    cars = json.load(json_file)

# %%
cars
# Out:
# {'_via_settings': {'ui': {'annotation_editor_height': 25,
#    'annotation_editor_fontsize': 0.8,
#    'leftsidebar_width': 18,
#    'image_grid': {'img_height': 80,
#     'rshape_fill': 'none',
#     'rshape_fill_opacity': 0.3,
#     'rshape_stroke': 'yellow',
#     'rshape_stroke_width': 2,
#     'show_region_shape': True,
#     'show_image_policy': 'all'},
#    'image': {'region_label': '__via_region_id__',
#     'region_color': '__via_default_region_color__',
#     'region_label_font': '10px Sans',
#     'on_image_annotation_editor_placement': 'NEAR_REGION'}},
#   'core': {'buffer_size': 18, 'filepath': {}, 'default_filepath': ''},
#   'project': {'name': 'cars'}},
#  '_via_img_metadata': {'PXL_20230113_135530132.jpg5639597': {'filename': 'PXL_20230113_135530132.jpg',
#    'size': 5639597,
#    'regions': [{'shape_attributes': {'name': 'rect',
#       'x': 995,
#       'y': 882,
#       'width': 1871,
#       'height': 758},
#      'region_attributes': {}}],
# ...
